# %%
import numpy as np
import matplotlib.pyplot as plt
X,Y = np.meshgrid(np.linspace(-100,100,50), np.linspace(-100,100,20))
U=Y
V=-X
Un= U / np.sqrt(U*U + V*V)
Vn = V / np.sqrt(U*U + V*V)
fig = plt.quiver(X,Y,Un,Vn)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-1a46e549eae6> in <module>
#       7 Vn = V / np.sqrt(U*U + V*V)
#       8 fig = plt.quiver(X,Y,Un,Vn)
# ----> 9 fig.savefig('a.png')
#      10
#      11
#
# AttributeError: 'Quiver' object has no attribute 'savefig'
